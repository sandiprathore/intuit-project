# %%
# import pandas as pd
# train = pd.DataFrame.from_dict(data, orient='index')

# %%
import requests

url = "https://api.notion.com/v1/databases/286284d1da044717a690fcf0140cb693/query"

payload = {"page_size": 100}
headers = {
    "Accept": "application/json",
    "Notion-Version": "2022-02-22",
    "Content-Type": "application/json",
    "Authorization": "Bearer secret_pYTl1vE3fuHYoVtI45ejgLVQqqDyn2WQhLDaZH8cUYD"
}

response = requests.post(url, json=payload, headers=headers)

data = (response.json())



# final_data = []
# for i in data['results']:
#     name_dict = (i['properties']['Name']['title'])
#     for n in name_dict:
#         name = n['plain_text']
#     tage_dict = (i['properties']['Tags']['multi_select'])
#     # print(type(tage_dict))
#     #     # print(name)
    
    
    # class_d =i['properties']['class']['rich_text'][0]['plain_text']
    # print(class_d)
    # dict_f =  {"Name": name,
    #               "Tage":tage_dict,
    #            "class": class_d}
    # final_data.append(dict_f)

# %%
for result in results:
    properties = result['properties']
    Tags =  properties['Tags']['multi_select']
    Name =  
#     for prop in properties:
#         print(prop)
# Out:
# [{'id': '1e4a1262-101f-4e3d-938d-3b29af0b0ced', 'name': 'Tag-C', 'color': 'gray'}]
# [{'id': '48ef2959-105b-4b23-9640-f4da7a093b92', 'name': 'Tag-D', 'color': 'yellow'}, {'id': '1e4a1262-101f-4e3d-938d-3b29af0b0ced', 'name': 'Tag-C', 'color': 'gray'}]
# [{'id': '386f03e0-794a-471a-9614-1d6be0093643', 'name': 'Tag-A', 'color': 'pink'}]

# %%
df = pd.DataFrame(data['results'])

# %%
results = data['results']
results
# Out:
# [{'object': 'page',
#   'id': '89da8b29-3b88-4842-b530-e0ea25cb41d0',
#   'created_time': '2022-07-01T11:13:00.000Z',
#   'last_edited_time': '2022-07-04T08:48:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '08c6db61-57a6-44a1-8937-22b1d03fcba2'},
#   'last_edited_by': {'object': 'user',
#    'id': '08c6db61-57a6-44a1-8937-22b1d03fcba2'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': '286284d1-da04-4717-a690-fcf0140cb693'},
#   'archived': False,
#   'properties': {'Tags': {'id': '%3Fjbh',
#     'type': 'multi_select',
#     'multi_select': [{'id': '1e4a1262-101f-4e3d-938d-3b29af0b0ced',
#       'name': 'Tag-C',
#       'color': 'gray'}]},
#    'SCHOOL': {'id': 'EE%40A',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': 'SICN', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
# ...
